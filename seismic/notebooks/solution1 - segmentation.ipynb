# %% [markdown]
# ## Plan
# 1. use 2d unet from [segmentation_models.pytorch](https://github.com/qubvel/segmentation_models.pytorch) repo
# 2. add cv with n folds (let's start with n = 5)
# 3. train on:
#   - resized image
#   - image fragments

# %%
import torch
import numpy as np
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm.notebook import tqdm
import cv2

# %%
#!pip install --upgrade segmentation-models-pytorch
SEED = 2768
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
import segmentation_models_pytorch as smp

# %%
with np.load('../data/data_train.npz') as dataset:
        train_dataset = dataset['data']
        
with np.load('../data/data_test_1.npz') as dataset:
        test_dataset = dataset['data']

with np.load('../data/labels_train.npz') as labels:
        train_labels = labels['labels']

# %%
def fast_glcm(img, vmin=0, vmax=255, nbit=8, kernel_size=5):
    mi, ma = vmin, vmax
    ks = kernel_size
    h,w = img.shape

    # digitize
    bins = np.linspace(mi, ma+1, nbit+1)
    gl1 = np.digitize(img, bins) - 1
    gl2 = np.append(gl1[:,1:], gl1[:,-1:], axis=1)

    # make glcm
    glcm = np.zeros((nbit, nbit, h, w), dtype=np.uint8)
    for i in range(nbit):
        for j in range(nbit):
            mask = ((gl1==i) & (gl2==j))
            glcm[i,j, mask] = 1

    kernel = np.ones((ks, ks), dtype=np.uint8)
    for i in range(nbit):
        for j in range(nbit):
            glcm[i,j] = cv2.filter2D(glcm[i,j], -1, kernel)

    glcm = glcm.astype(np.float32)
    return glcm

def fast_glcm_max(img, vmin=0, vmax=255, nbit=2, ks=5):
    '''
    calc glcm max
    '''
    glcm = fast_glcm(img, vmin, vmax, nbit, ks)
    max_  = np.max(glcm, axis=(0,1))
    return max_

# Preprocessing our image, inclusing  applying fast_glcm_max function, resizing and normalizing pixel values 
def process_img_label(img, label=None):

    img = fast_glcm_max(img)

    img = np.expand_dims(img, axis=2)#.astype('float32')


    img = cv2.resize(img, (224, 224))


    img = cv2.normalize(img, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX).astype(np.uint8)

    try:
        label = np.expand_dims(label, axis=2).astype(np.uint8)
        label = cv2.resize(label, (224, 224))

        return img, label

    except:
        return img

# %%
test_dataset.shape
# Out:
# (1006, 782, 251)

# %%
training_img_data = []
test_img_data = []
training_label_data = []

for i in tqdm(range(0, 590)):
    img = train_dataset[:, :, i]
    label = train_labels[:, :, i]

    img, label = process_img_label(img, label)

    training_img_data.append(img) 
    training_label_data.append(label)
for i in tqdm(range(0, 251)):
    img = test_dataset[:, :, i]
    img = process_img_label(img)
    test_img_data.append(img)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=590.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=251.0), HTML(value='')))
# /home/lacemaker/anaconda3/envs/data_env/lib/python3.7/site-packages/ipykernel_launcher.py:48: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.

# %%
training_img_data = np.asarray(training_img_data)
test_img_data = np.asarray(test_img_data)
training_label_data = np.asarray(training_label_data)
training_img_data = np.expand_dims(training_img_data, 1)
test_img_data = np.expand_dims(test_img_data, 1)
training_img_data.shape, training_label_data.shape, test_img_data.shape
# Out:
# ((590, 1, 224, 224), (590, 224, 224), (251, 1, 224, 224))

# %%
import solt
import solt.transforms as slt

stream = solt.Stream([
    slt.Rotate(angle_range=(0, 360), p=1, padding='r'),
     slt.Shear(range_x=0.3, range_y=0.8, p=0.5, padding='r'),
     slt.Flip(axis=1, p=0.5),
    slt.Flip(axis=0, p=0.5),
    #  slt.IntensityRemap(),
    slt.Brightness(brightness_range=(0, 1)),
     slt.Pad(200),
     slt.Scale(range_x=(0.8, 1.3), padding='r', range_y=(0.8, 1.3), same=False, p=0.5),
     slt.Contrast(p=0.5),
    #   solt.SelectiveStream([
    #     slt.CutOut(40, p=1),
    #     slt.CutOut(50, p=1),
    #     slt.CutOut(10, p=1),
    #     solt.Stream(),
    #     solt.Stream(),
    # ], n=3),
    # slt.Crop((224, 224)),
    solt.SelectiveStream([
        slt.GammaCorrection(gamma_range=0.5, p=1),
        slt.Noise(gain_range=0.1, p=1),
        slt.Blur()    
    ], n=3)
])

# %% [raw]
# one_hot_train_label_data = []
# n=0
#
# labels = np.unique(training_label_data)
# labels_dict = {x: i for i, x in enumerate(labels)}
# to_dict = np.vectorize(lambda x: labels_dict.get(x), otypes=[int])
# labels_eye = np.eye(len(labels))
#
# for img in training_label_data:
#
#     img = img.astype(int)
#     img = to_dict(img).astype(int)
#
#     one_hot_train_label_data.append(labels_eye[img])
#
# one_hot_train_label_data = np.array(one_hot_train_label_data)
#
# one_hot_train_label_data.shape

# %%
ENCODER = 'resnet34' #'se_resnext50_32x4d'
ENCODER_WEIGHTS = 'imagenet'

ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multicalss segmentation
DEVICE = 'cuda'

# create segmentation model with pretrained encoder

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
#model(torch.randn(10, 1, 224, 224)).shape

# %%
training_img_data.shape
# Out:
# (590, 1, 224, 224)

# %%
from sklearn.model_selection import KFold

# %%
import albumentations as albu

def get_training_augmentation(size=224):
    train_transform = [

        albu.HorizontalFlip(p=0.5),

        albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        albu.PadIfNeeded(min_height=size, min_width=size, always_apply=True, border_mode=0),
        albu.RandomCrop(height=size, width=size, always_apply=True),

        albu.IAAAdditiveGaussianNoise(p=0.2),
        albu.IAAPerspective(p=0.5),

        albu.OneOf(
            [
                albu.CLAHE(p=1),
                albu.RandomBrightness(p=1),
                albu.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.IAASharpen(p=1),
                albu.Blur(blur_limit=3, p=1),
                albu.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.RandomContrast(p=1),
                albu.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation(do_pad=False):
    """Add paddings to make image shape divisible by 32"""
    if do_pad:
        test_transform = [
        albu.PadIfNeeded(384, 480)
        ]
    else:
        test_transform = []
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %%
from torch.utils.data import Dataset, DataLoader

#img_aug, mask_aug = stream({'image': train_data[:, 0], 'mask':train_labels[:,0]}, return_torch=False, ).data
class SeismicDataset(Dataset):
    def __init__(self, data, mask_data=None, transform=None, augmentation=None, preprocessing=None, labels=[]):
        self.data = data
        self.mask_data = mask_data
        self.transform = transform
        self.augmentation=augmentation
        self.preprocessing = preprocessing
        self.labels=labels
        
    def __len__(self):
        return self.data.shape[0]
    
    def __getitem__(self, idx):
        img = self.data[idx, 0]
        img_new = np.zeros(img.shape + (3,), dtype=img.dtype)
        for i in range(3):
            img_new[:, :, i] = img[:, :]
        img = img_new
        #print(img.shape, img.dtype)
        if self.mask_data is None:
            if self.transform is not None:
                img = self.transform(img)
            if self.augmentation:
                sample = self.augmentation(image=img)
                img = sample['image']

            # apply preprocessing
            if self.preprocessing:
                sample = self.preprocessing(image=img)
                img = sample['image']
            return img
        mask = self.mask_data[idx]
        masks = np.zeros(mask.shape+(len(self.labels), ), dtype=np.float)
        for i, label in enumerate(self.labels):
            masks[:, :, i] = mask[:, :] == label
            #print(np.sum(mask==label))
        #if self.transform is not None:
        #    img, label = self.transform(img, label)
        if self.augmentation:
            sample = self.augmentation(image=img, mask=masks)
            img, masks = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=img, mask=masks)
            img, masks = sample['image'], sample['mask']
            
        return img, masks

# %%
# train model for 40 epochs
def do_train(model, train_epoch, valid_epoch, train_loader, val_loader, n_epochs=40, fold=0):
    max_score = 0

    for i in range(0, n_epochs):

        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(val_loader)

        # do something (save model, change lr, etc.)
        if max_score < valid_logs['iou_score']:
            max_score = valid_logs['iou_score']
            torch.save(model, f'./solution1/best_model_{fold}.pth')
            print('Model saved!')

        if i == 25:
            optimizer.param_groups[0]['lr'] = 1e-5
            print('Decrease decoder learning rate to 1e-5!')

# %%
loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

ACTIVATION = 'softmax2d' # could be None for logits or 'softmax2d' for multicalss segmentation
NFOLDS=5
labels = np.unique(training_label_data)

# %%
kf = KFold(random_state=SEED, n_splits=NFOLDS, shuffle=True)
for fold, (train_ids, val_ids) in enumerate(kf.split(training_img_data)):
    train_data = training_img_data[train_ids]
    train_labels = training_label_data[train_ids]
    val_data = training_img_data[val_ids]
    val_labels = training_label_data[val_ids]
    
    train_ds = SeismicDataset(
        train_data, train_labels,
        preprocessing=get_preprocessing(preprocessing_fn),
        augmentation=get_training_augmentation(),
        labels=labels
    )
    val_ds = SeismicDataset(
        val_data, val_labels,
        preprocessing=get_preprocessing(preprocessing_fn),
        augmentation=get_validation_augmentation(),
        labels=labels
    )
    
    train_loader = DataLoader(train_ds, batch_size=32)
    val_loader = DataLoader(val_ds, batch_size=4)
    model = smp.Unet(
        ENCODER, classes=len(labels), in_channels=3,
        encoder_weights=ENCODER_WEIGHTS,
        activation=ACTIVATION,
    )
    
    optimizer = torch.optim.Adam([ 
        dict(params=model.parameters(), lr=0.0001),
    ])

    train_epoch = smp.utils.train.TrainEpoch(
        model, 
        loss=loss, 
        metrics=metrics, 
        optimizer=optimizer,
        device=DEVICE,
        verbose=True,
    )

    valid_epoch = smp.utils.train.ValidEpoch(
        model, 
        loss=loss, 
        metrics=metrics, 
        device=DEVICE,
        verbose=True,
    )

    do_train(model, train_epoch, valid_epoch, train_loader, val_loader, fold=fold)
    #break
# Out:
# Epoch: 0
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.8098, iou_score - 0.05058]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.47it/s, dice_loss - 0.7736, iou_score - 0.08398]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 15/15 [00:06<00:00,  2.32it/s, dice_loss - 0.7575, iou_score - 0.1472]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.06it/s, dice_loss - 0.7013, iou_score - 0.1951]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 15/15 [00:06<00:00,  2.32it/s, dice_loss - 0.713, iou_score - 0.2209]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.10it/s, dice_loss - 0.6391, iou_score - 0.2614]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.6592, iou_score - 0.2838]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.87it/s, dice_loss - 0.5893, iou_score - 0.3124]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.6109, iou_score - 0.3386]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.67it/s, dice_loss - 0.5555, iou_score - 0.3319]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.5713, iou_score - 0.3718]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.54it/s, dice_loss - 0.5103, iou_score - 0.3683]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.5381, iou_score - 0.3925]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.17it/s, dice_loss - 0.4689, iou_score - 0.3689]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.5032, iou_score - 0.4073]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.32it/s, dice_loss - 0.4421, iou_score - 0.3694]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.4794, iou_score - 0.4515]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.73it/s, dice_loss - 0.4077, iou_score - 0.5749]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.4551, iou_score - 0.5539]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.34it/s, dice_loss - 0.3983, iou_score - 0.6021]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.4468, iou_score - 0.5772]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.66it/s, dice_loss - 0.3837, iou_score - 0.5967]
#
# Epoch: 11
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.4199, iou_score - 0.6143]
# valid: 100%|██████████| 30/30 [00:00<00:00, 45.89it/s, dice_loss - 0.313, iou_score - 0.7061]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.4122, iou_score - 0.6154]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.47it/s, dice_loss - 0.3074, iou_score - 0.6692]
#
# Epoch: 13
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.3875, iou_score - 0.6354]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.04it/s, dice_loss - 0.2684, iou_score - 0.7085]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 15/15 [00:06<00:00,  2.18it/s, dice_loss - 0.3508, iou_score - 0.6631]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.56it/s, dice_loss - 0.2568, iou_score - 0.7152]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.3547, iou_score - 0.6464]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.90it/s, dice_loss - 0.2433, iou_score - 0.7231]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.3378, iou_score - 0.6638]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.55it/s, dice_loss - 0.2269, iou_score - 0.742]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.3305, iou_score - 0.6743]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.09it/s, dice_loss - 0.1987, iou_score - 0.7693]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.298, iou_score - 0.7188]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.77it/s, dice_loss - 0.1899, iou_score - 0.7841]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2821, iou_score - 0.7296]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.95it/s, dice_loss - 0.1754, iou_score - 0.8027]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2822, iou_score - 0.7255]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.63it/s, dice_loss - 0.1855, iou_score - 0.7758]
#
# Epoch: 21
# train: 100%|██████████| 15/15 [00:07<00:00,  2.05it/s, dice_loss - 0.2741, iou_score - 0.732]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.06it/s, dice_loss - 0.1757, iou_score - 0.7773]
#
# Epoch: 22
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.2633, iou_score - 0.7445]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.78it/s, dice_loss - 0.1654, iou_score - 0.7934]
#
# Epoch: 23
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.2774, iou_score - 0.716]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.89it/s, dice_loss - 0.1652, iou_score - 0.7831]
#
# Epoch: 24
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.2725, iou_score - 0.7232]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.71it/s, dice_loss - 0.163, iou_score - 0.7824]
#
# Epoch: 25
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.2621, iou_score - 0.7344]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.08it/s, dice_loss - 0.1561, iou_score - 0.7965]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.2456, iou_score - 0.7581]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.08it/s, dice_loss - 0.1419, iou_score - 0.8178]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.2493, iou_score - 0.7662]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.80it/s, dice_loss - 0.1345, iou_score - 0.8274]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.2381, iou_score - 0.7775]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.23it/s, dice_loss - 0.1325, iou_score - 0.8345]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2395, iou_score - 0.7807]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.21it/s, dice_loss - 0.1297, iou_score - 0.8387]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 15/15 [00:06<00:00,  2.21it/s, dice_loss - 0.2342, iou_score - 0.7849]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.21it/s, dice_loss - 0.1283, iou_score - 0.8428]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.2332, iou_score - 0.7933]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.03it/s, dice_loss - 0.1268, iou_score - 0.8453]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 15/15 [00:06<00:00,  2.32it/s, dice_loss - 0.2319, iou_score - 0.7946]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.27it/s, dice_loss - 0.1249, iou_score - 0.8472]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.2412, iou_score - 0.786]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.76it/s, dice_loss - 0.1224, iou_score - 0.8486]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2414, iou_score - 0.7889]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.61it/s, dice_loss - 0.121, iou_score - 0.8495]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 15/15 [00:06<00:00,  2.31it/s, dice_loss - 0.2255, iou_score - 0.8008]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.48it/s, dice_loss - 0.1216, iou_score - 0.8509]
# Model saved!
#
# Epoch: 36
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2245, iou_score - 0.8037]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.49it/s, dice_loss - 0.1222, iou_score - 0.8496]
#
# Epoch: 37
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2241, iou_score - 0.803]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.30it/s, dice_loss - 0.1196, iou_score - 0.8525]
# Model saved!
#
# Epoch: 38
# train: 100%|██████████| 15/15 [00:06<00:00,  2.31it/s, dice_loss - 0.2272, iou_score - 0.8044]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.99it/s, dice_loss - 0.1193, iou_score - 0.852]
#
# Epoch: 39
# train: 100%|██████████| 15/15 [00:06<00:00,  2.31it/s, dice_loss - 0.2265, iou_score - 0.805]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.47it/s, dice_loss - 0.1181, iou_score - 0.8539]
# Model saved!
#
# Epoch: 0
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.8552, iou_score - 0.01866]
# valid: 100%|██████████| 30/30 [00:00<00:00, 52.20it/s, dice_loss - 0.8323, iou_score - 0.02898]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.8073, iou_score - 0.03951]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.07it/s, dice_loss - 0.7736, iou_score - 0.02664]
#
# Epoch: 2
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.7575, iou_score - 0.1135]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.89it/s, dice_loss - 0.6579, iou_score - 0.2524]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.7031, iou_score - 0.2281]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.90it/s, dice_loss - 0.5493, iou_score - 0.3926]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.6424, iou_score - 0.3252]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.88it/s, dice_loss - 0.5347, iou_score - 0.4329]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.5744, iou_score - 0.4146]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.18it/s, dice_loss - 0.4487, iou_score - 0.5008]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.5221, iou_score - 0.5048]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.46it/s, dice_loss - 0.4095, iou_score - 0.5838]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.4914, iou_score - 0.552]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.32it/s, dice_loss - 0.3694, iou_score - 0.6389]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.4714, iou_score - 0.5678]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.76it/s, dice_loss - 0.3709, iou_score - 0.6234]
#
# Epoch: 9
# train: 100%|██████████| 15/15 [00:06<00:00,  2.32it/s, dice_loss - 0.4579, iou_score - 0.5632]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.49it/s, dice_loss - 0.3294, iou_score - 0.6691]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.4353, iou_score - 0.5822]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.50it/s, dice_loss - 0.36, iou_score - 0.5936]
#
# Epoch: 11
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.4235, iou_score - 0.593]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.95it/s, dice_loss - 0.3075, iou_score - 0.6703]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.4009, iou_score - 0.6115]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.31it/s, dice_loss - 0.29, iou_score - 0.6669]
#
# Epoch: 13
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.3921, iou_score - 0.6018]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.40it/s, dice_loss - 0.2771, iou_score - 0.6788]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.383, iou_score - 0.6154]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.03it/s, dice_loss - 0.2555, iou_score - 0.6953]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.3628, iou_score - 0.6352]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.55it/s, dice_loss - 0.2457, iou_score - 0.7104]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.3563, iou_score - 0.6459]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.43it/s, dice_loss - 0.2307, iou_score - 0.7179]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.3363, iou_score - 0.6614]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.08it/s, dice_loss - 0.2316, iou_score - 0.7213]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.3408, iou_score - 0.6568]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.41it/s, dice_loss - 0.2139, iou_score - 0.7291]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.3335, iou_score - 0.6663]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.20it/s, dice_loss - 0.2113, iou_score - 0.7258]
#
# Epoch: 20
# train: 100%|██████████| 15/15 [00:06<00:00,  2.14it/s, dice_loss - 0.3146, iou_score - 0.6752]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.81it/s, dice_loss - 0.2049, iou_score - 0.7373]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.3103, iou_score - 0.6748]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.71it/s, dice_loss - 0.1981, iou_score - 0.7378]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3041, iou_score - 0.688]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.20it/s, dice_loss - 0.1929, iou_score - 0.7465]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2998, iou_score - 0.7008]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.84it/s, dice_loss - 0.1775, iou_score - 0.7759]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.2886, iou_score - 0.7411]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.49it/s, dice_loss - 0.1647, iou_score - 0.7971]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2701, iou_score - 0.7547]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.32it/s, dice_loss - 0.173, iou_score - 0.7742]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.2783, iou_score - 0.738]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.88it/s, dice_loss - 0.1593, iou_score - 0.797]
#
# Epoch: 27
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.2617, iou_score - 0.7654]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.76it/s, dice_loss - 0.1513, iou_score - 0.8128]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 15/15 [00:06<00:00,  2.18it/s, dice_loss - 0.2547, iou_score - 0.7725]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.69it/s, dice_loss - 0.1491, iou_score - 0.8179]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.2625, iou_score - 0.7737]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.25it/s, dice_loss - 0.148, iou_score - 0.8142]
#
# Epoch: 30
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2622, iou_score - 0.7734]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.31it/s, dice_loss - 0.1447, iou_score - 0.82]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2579, iou_score - 0.7789]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.74it/s, dice_loss - 0.1423, iou_score - 0.8231]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2507, iou_score - 0.7828]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.39it/s, dice_loss - 0.1408, iou_score - 0.8256]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.252, iou_score - 0.7872]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.49it/s, dice_loss - 0.1354, iou_score - 0.8319]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.2484, iou_score - 0.7923]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.84it/s, dice_loss - 0.1333, iou_score - 0.8339]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.2502, iou_score - 0.7922]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.36it/s, dice_loss - 0.1328, iou_score - 0.8327]
#
# Epoch: 36
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.2468, iou_score - 0.7969]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.46it/s, dice_loss - 0.1302, iou_score - 0.8383]
# Model saved!
#
# Epoch: 37
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2457, iou_score - 0.8018]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.39it/s, dice_loss - 0.1309, iou_score - 0.8365]
#
# Epoch: 38
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2429, iou_score - 0.8018]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.63it/s, dice_loss - 0.1307, iou_score - 0.8386]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2426, iou_score - 0.8024]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.82it/s, dice_loss - 0.1298, iou_score - 0.8411]
# Model saved!
#
# Epoch: 0
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.7296, iou_score - 0.1741]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.47it/s, dice_loss - 0.6915, iou_score - 0.1968]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.6547, iou_score - 0.2894]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.17it/s, dice_loss - 0.5362, iou_score - 0.4151]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.5854, iou_score - 0.3839]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.75it/s, dice_loss - 0.4459, iou_score - 0.5185]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 15/15 [00:06<00:00,  2.21it/s, dice_loss - 0.5199, iou_score - 0.4572]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.10it/s, dice_loss - 0.3599, iou_score - 0.589]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.4564, iou_score - 0.5264]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.08it/s, dice_loss - 0.3524, iou_score - 0.5727]
#
# Epoch: 5
# train: 100%|██████████| 15/15 [00:06<00:00,  2.18it/s, dice_loss - 0.42, iou_score - 0.5532]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.95it/s, dice_loss - 0.3349, iou_score - 0.5804]
#
# Epoch: 6
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.3989, iou_score - 0.5669]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.26it/s, dice_loss - 0.3129, iou_score - 0.6111]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.3793, iou_score - 0.5869]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.68it/s, dice_loss - 0.2512, iou_score - 0.6813]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.3626, iou_score - 0.5952]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.59it/s, dice_loss - 0.2369, iou_score - 0.6986]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.3559, iou_score - 0.5989]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.77it/s, dice_loss - 0.2341, iou_score - 0.6924]
#
# Epoch: 10
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3551, iou_score - 0.5992]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.33it/s, dice_loss - 0.2487, iou_score - 0.6565]
#
# Epoch: 11
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.3446, iou_score - 0.6103]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.51it/s, dice_loss - 0.2143, iou_score - 0.7054]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3365, iou_score - 0.621]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.62it/s, dice_loss - 0.2198, iou_score - 0.6937]
#
# Epoch: 13
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3456, iou_score - 0.6118]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.01it/s, dice_loss - 0.1938, iou_score - 0.7236]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.3284, iou_score - 0.6227]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.96it/s, dice_loss - 0.2174, iou_score - 0.6947]
#
# Epoch: 15
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3288, iou_score - 0.6106]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.01it/s, dice_loss - 0.1873, iou_score - 0.7207]
#
# Epoch: 16
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.3151, iou_score - 0.6294]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.55it/s, dice_loss - 0.1879, iou_score - 0.734]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.3087, iou_score - 0.6438]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.38it/s, dice_loss - 0.1941, iou_score - 0.7178]
#
# Epoch: 18
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.3073, iou_score - 0.6378]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.94it/s, dice_loss - 0.1712, iou_score - 0.7451]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2995, iou_score - 0.6442]
# valid: 100%|██████████| 30/30 [00:00<00:00, 45.76it/s, dice_loss - 0.1744, iou_score - 0.7371]
#
# Epoch: 20
# train: 100%|██████████| 15/15 [00:07<00:00,  2.08it/s, dice_loss - 0.3, iou_score - 0.6406]
# valid: 100%|██████████| 30/30 [00:00<00:00, 45.39it/s, dice_loss - 0.1726, iou_score - 0.7332]
#
# Epoch: 21
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.287, iou_score - 0.6642]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.28it/s, dice_loss - 0.1756, iou_score - 0.7492]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.2834, iou_score - 0.6811]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.66it/s, dice_loss - 0.1864, iou_score - 0.7266]
#
# Epoch: 23
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2943, iou_score - 0.6616]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.40it/s, dice_loss - 0.1673, iou_score - 0.7527]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2859, iou_score - 0.6725]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.95it/s, dice_loss - 0.1369, iou_score - 0.797]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2491, iou_score - 0.7217]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.89it/s, dice_loss - 0.1394, iou_score - 0.7919]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.2469, iou_score - 0.7248]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.56it/s, dice_loss - 0.1288, iou_score - 0.8103]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2482, iou_score - 0.7286]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.07it/s, dice_loss - 0.1245, iou_score - 0.8166]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.2429, iou_score - 0.7353]
# valid: 100%|██████████| 30/30 [00:00<00:00, 45.51it/s, dice_loss - 0.123, iou_score - 0.8207]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.2395, iou_score - 0.7437]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.83it/s, dice_loss - 0.1226, iou_score - 0.8203]
#
# Epoch: 30
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.2349, iou_score - 0.7447]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.08it/s, dice_loss - 0.1217, iou_score - 0.8235]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2347, iou_score - 0.7466]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.06it/s, dice_loss - 0.1212, iou_score - 0.825]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2358, iou_score - 0.7468]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.68it/s, dice_loss - 0.1202, iou_score - 0.8252]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2312, iou_score - 0.7464]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.45it/s, dice_loss - 0.1196, iou_score - 0.8255]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.2484, iou_score - 0.7369]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.99it/s, dice_loss - 0.1174, iou_score - 0.8265]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.2428, iou_score - 0.7393]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.67it/s, dice_loss - 0.1171, iou_score - 0.8288]
# Model saved!
#
# Epoch: 36
# train: 100%|██████████| 15/15 [00:06<00:00,  2.31it/s, dice_loss - 0.2482, iou_score - 0.7434]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.29it/s, dice_loss - 0.1162, iou_score - 0.8273]
#
# Epoch: 37
# train: 100%|██████████| 15/15 [00:06<00:00,  2.30it/s, dice_loss - 0.2262, iou_score - 0.756]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.80it/s, dice_loss - 0.1174, iou_score - 0.8288]
#
# Epoch: 38
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.2358, iou_score - 0.7496]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.44it/s, dice_loss - 0.1156, iou_score - 0.8304]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.2348, iou_score - 0.7478]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.07it/s, dice_loss - 0.1154, iou_score - 0.8313]
# Model saved!
#
# Epoch: 0
# train: 100%|██████████| 15/15 [00:06<00:00,  2.28it/s, dice_loss - 0.7853, iou_score - 0.08513]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.65it/s, dice_loss - 0.749, iou_score - 0.09448]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.7197, iou_score - 0.2016]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.68it/s, dice_loss - 0.6112, iou_score - 0.3069]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 15/15 [00:07<00:00,  2.06it/s, dice_loss - 0.6714, iou_score - 0.2825]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.64it/s, dice_loss - 0.5545, iou_score - 0.3556]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.6276, iou_score - 0.331]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.36it/s, dice_loss - 0.5309, iou_score - 0.3702]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.5761, iou_score - 0.3763]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.94it/s, dice_loss - 0.4925, iou_score - 0.4464]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 15/15 [00:07<00:00,  2.11it/s, dice_loss - 0.5268, iou_score - 0.448]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.32it/s, dice_loss - 0.4399, iou_score - 0.5021]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.4812, iou_score - 0.5211]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.31it/s, dice_loss - 0.3657, iou_score - 0.6442]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 15/15 [00:07<00:00,  2.09it/s, dice_loss - 0.4367, iou_score - 0.5986]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.12it/s, dice_loss - 0.302, iou_score - 0.724]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 15/15 [00:07<00:00,  2.12it/s, dice_loss - 0.4061, iou_score - 0.6422]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.70it/s, dice_loss - 0.3213, iou_score - 0.6741]
#
# Epoch: 9
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.3885, iou_score - 0.6515]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.25it/s, dice_loss - 0.2811, iou_score - 0.7012]
#
# Epoch: 10
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.3645, iou_score - 0.6675]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.38it/s, dice_loss - 0.31, iou_score - 0.6477]
#
# Epoch: 11
# train: 100%|██████████| 15/15 [00:06<00:00,  2.18it/s, dice_loss - 0.3505, iou_score - 0.6749]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.84it/s, dice_loss - 0.2404, iou_score - 0.7388]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 15/15 [00:06<00:00,  2.19it/s, dice_loss - 0.3416, iou_score - 0.6828]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.03it/s, dice_loss - 0.2269, iou_score - 0.7376]
#
# Epoch: 13
# train: 100%|██████████| 15/15 [00:07<00:00,  2.12it/s, dice_loss - 0.3414, iou_score - 0.6621]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.37it/s, dice_loss - 0.3113, iou_score - 0.5999]
#
# Epoch: 14
# train: 100%|██████████| 15/15 [00:06<00:00,  2.14it/s, dice_loss - 0.3481, iou_score - 0.6427]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.76it/s, dice_loss - 0.2002, iou_score - 0.7548]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.3298, iou_score - 0.6586]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.56it/s, dice_loss - 0.1939, iou_score - 0.7585]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.3017, iou_score - 0.7013]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.74it/s, dice_loss - 0.1796, iou_score - 0.7779]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.2934, iou_score - 0.7154]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.96it/s, dice_loss - 0.1815, iou_score - 0.7634]
#
# Epoch: 18
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.2809, iou_score - 0.7258]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.11it/s, dice_loss - 0.1648, iou_score - 0.7859]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 15/15 [00:07<00:00,  2.12it/s, dice_loss - 0.2821, iou_score - 0.7087]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.33it/s, dice_loss - 0.1559, iou_score - 0.7961]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.2667, iou_score - 0.7381]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.54it/s, dice_loss - 0.1584, iou_score - 0.7896]
#
# Epoch: 21
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.27, iou_score - 0.7298]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.91it/s, dice_loss - 0.1438, iou_score - 0.8049]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 15/15 [00:07<00:00,  2.12it/s, dice_loss - 0.262, iou_score - 0.7389]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.28it/s, dice_loss - 0.15, iou_score - 0.79]
#
# Epoch: 23
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.2582, iou_score - 0.7407]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.97it/s, dice_loss - 0.138, iou_score - 0.8105]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.2569, iou_score - 0.7485]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.55it/s, dice_loss - 0.1416, iou_score - 0.7969]
#
# Epoch: 25
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.2566, iou_score - 0.7451]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.27it/s, dice_loss - 0.1308, iou_score - 0.8107]
# Model saved!
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.248, iou_score - 0.7528]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.60it/s, dice_loss - 0.1223, iou_score - 0.8282]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.2385, iou_score - 0.7704]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.27it/s, dice_loss - 0.1197, iou_score - 0.8314]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.2291, iou_score - 0.7785]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.57it/s, dice_loss - 0.1199, iou_score - 0.8327]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 15/15 [00:07<00:00,  2.10it/s, dice_loss - 0.2337, iou_score - 0.7789]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.43it/s, dice_loss - 0.1178, iou_score - 0.8337]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 15/15 [00:07<00:00,  2.09it/s, dice_loss - 0.2191, iou_score - 0.7844]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.12it/s, dice_loss - 0.1185, iou_score - 0.8366]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 15/15 [00:07<00:00,  2.11it/s, dice_loss - 0.2325, iou_score - 0.7796]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.27it/s, dice_loss - 0.1169, iou_score - 0.8359]
#
# Epoch: 32
# train: 100%|██████████| 15/15 [00:07<00:00,  2.05it/s, dice_loss - 0.2253, iou_score - 0.7825]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.75it/s, dice_loss - 0.1176, iou_score - 0.8368]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 15/15 [00:07<00:00,  2.09it/s, dice_loss - 0.2272, iou_score - 0.7799]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.70it/s, dice_loss - 0.116, iou_score - 0.8384]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.2356, iou_score - 0.7773]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.00it/s, dice_loss - 0.1155, iou_score - 0.8382]
#
# Epoch: 35
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.2292, iou_score - 0.7825]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.32it/s, dice_loss - 0.1151, iou_score - 0.8403]
# Model saved!
#
# Epoch: 36
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.2353, iou_score - 0.7786]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.66it/s, dice_loss - 0.1143, iou_score - 0.8396]
#
# Epoch: 37
# train: 100%|██████████| 15/15 [00:07<00:00,  2.12it/s, dice_loss - 0.2297, iou_score - 0.7835]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.70it/s, dice_loss - 0.1134, iou_score - 0.8425]
# Model saved!
#
# Epoch: 38
# train: 100%|██████████| 15/15 [00:07<00:00,  2.10it/s, dice_loss - 0.2291, iou_score - 0.7834]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.68it/s, dice_loss - 0.1136, iou_score - 0.843]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.219, iou_score - 0.7914]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.84it/s, dice_loss - 0.1139, iou_score - 0.8444]
# Model saved!
#
# Epoch: 0
# train: 100%|██████████| 15/15 [00:06<00:00,  2.18it/s, dice_loss - 0.8386, iou_score - 0.04616]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.16it/s, dice_loss - 0.7687, iou_score - 0.1077]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 15/15 [00:07<00:00,  2.11it/s, dice_loss - 0.7659, iou_score - 0.1084]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.54it/s, dice_loss - 0.665, iou_score - 0.1807]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 15/15 [00:07<00:00,  2.09it/s, dice_loss - 0.7143, iou_score - 0.1549]
# valid: 100%|██████████| 30/30 [00:00<00:00, 45.79it/s, dice_loss - 0.5935, iou_score - 0.2594]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.641, iou_score - 0.2878]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.70it/s, dice_loss - 0.5138, iou_score - 0.4194]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 15/15 [00:06<00:00,  2.15it/s, dice_loss - 0.5919, iou_score - 0.3892]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.07it/s, dice_loss - 0.4594, iou_score - 0.5226]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.5489, iou_score - 0.4642]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.32it/s, dice_loss - 0.4202, iou_score - 0.5711]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.5044, iou_score - 0.5141]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.98it/s, dice_loss - 0.3648, iou_score - 0.6454]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 15/15 [00:06<00:00,  2.19it/s, dice_loss - 0.4753, iou_score - 0.5402]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.43it/s, dice_loss - 0.3574, iou_score - 0.6373]
#
# Epoch: 8
# train: 100%|██████████| 15/15 [00:06<00:00,  2.21it/s, dice_loss - 0.4516, iou_score - 0.5549]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.06it/s, dice_loss - 0.3341, iou_score - 0.6449]
#
# Epoch: 9
# train: 100%|██████████| 15/15 [00:06<00:00,  2.29it/s, dice_loss - 0.4322, iou_score - 0.5651]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.29it/s, dice_loss - 0.3258, iou_score - 0.6343]
#
# Epoch: 10
# train: 100%|██████████| 15/15 [00:06<00:00,  2.27it/s, dice_loss - 0.4244, iou_score - 0.5662]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.83it/s, dice_loss - 0.285, iou_score - 0.6845]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 15/15 [00:06<00:00,  2.32it/s, dice_loss - 0.3831, iou_score - 0.6133]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.31it/s, dice_loss - 0.2459, iou_score - 0.7245]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.3512, iou_score - 0.6403]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.70it/s, dice_loss - 0.2338, iou_score - 0.7333]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 15/15 [00:07<00:00,  2.10it/s, dice_loss - 0.3376, iou_score - 0.6652]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.02it/s, dice_loss - 0.2134, iou_score - 0.7722]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 15/15 [00:06<00:00,  2.16it/s, dice_loss - 0.3238, iou_score - 0.6969]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.12it/s, dice_loss - 0.2153, iou_score - 0.7353]
#
# Epoch: 15
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.3142, iou_score - 0.6843]
# valid: 100%|██████████| 30/30 [00:00<00:00, 52.63it/s, dice_loss - 0.1883, iou_score - 0.7864]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.3022, iou_score - 0.7196]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.60it/s, dice_loss - 0.1849, iou_score - 0.7745]
#
# Epoch: 17
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2836, iou_score - 0.7167]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.03it/s, dice_loss - 0.1751, iou_score - 0.7775]
#
# Epoch: 18
# train: 100%|██████████| 15/15 [00:06<00:00,  2.21it/s, dice_loss - 0.276, iou_score - 0.7231]
# valid: 100%|██████████| 30/30 [00:00<00:00, 52.88it/s, dice_loss - 0.1721, iou_score - 0.7738]
#
# Epoch: 19
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2689, iou_score - 0.7309]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.56it/s, dice_loss - 0.1485, iou_score - 0.8103]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2546, iou_score - 0.7488]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.60it/s, dice_loss - 0.1519, iou_score - 0.7949]
#
# Epoch: 21
# train: 100%|██████████| 15/15 [00:06<00:00,  2.23it/s, dice_loss - 0.2572, iou_score - 0.7454]
# valid: 100%|██████████| 30/30 [00:00<00:00, 52.10it/s, dice_loss - 0.137, iou_score - 0.8098]
#
# Epoch: 22
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.2471, iou_score - 0.7518]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.87it/s, dice_loss - 0.1371, iou_score - 0.8072]
#
# Epoch: 23
# train: 100%|██████████| 15/15 [00:06<00:00,  2.25it/s, dice_loss - 0.2458, iou_score - 0.7527]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.17it/s, dice_loss - 0.128, iou_score - 0.8195]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 15/15 [00:06<00:00,  2.19it/s, dice_loss - 0.2262, iou_score - 0.7767]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.89it/s, dice_loss - 0.146, iou_score - 0.7884]
#
# Epoch: 25
# train: 100%|██████████| 15/15 [00:06<00:00,  2.21it/s, dice_loss - 0.2384, iou_score - 0.754]
# valid: 100%|██████████| 30/30 [00:00<00:00, 51.98it/s, dice_loss - 0.1227, iou_score - 0.8193]
# Decrease decoder learning rate to 1e-5!
#
# Epoch: 26
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.244, iou_score - 0.7525]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.37it/s, dice_loss - 0.1154, iou_score - 0.83]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.2154, iou_score - 0.7824]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.25it/s, dice_loss - 0.1103, iou_score - 0.8434]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2242, iou_score - 0.7869]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.82it/s, dice_loss - 0.1046, iou_score - 0.85]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 15/15 [00:06<00:00,  2.19it/s, dice_loss - 0.2067, iou_score - 0.8005]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.41it/s, dice_loss - 0.1045, iou_score - 0.8541]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 15/15 [00:06<00:00,  2.14it/s, dice_loss - 0.2087, iou_score - 0.7997]
# valid: 100%|██████████| 30/30 [00:00<00:00, 47.83it/s, dice_loss - 0.1032, iou_score - 0.8555]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 15/15 [00:07<00:00,  2.13it/s, dice_loss - 0.2159, iou_score - 0.8001]
# valid: 100%|██████████| 30/30 [00:00<00:00, 46.20it/s, dice_loss - 0.1006, iou_score - 0.8564]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 15/15 [00:07<00:00,  2.14it/s, dice_loss - 0.2047, iou_score - 0.8083]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.41it/s, dice_loss - 0.1011, iou_score - 0.8577]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 15/15 [00:06<00:00,  2.22it/s, dice_loss - 0.2091, iou_score - 0.8084]
# valid: 100%|██████████| 30/30 [00:00<00:00, 49.82it/s, dice_loss - 0.1001, iou_score - 0.858]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 15/15 [00:06<00:00,  2.26it/s, dice_loss - 0.2085, iou_score - 0.8077]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.89it/s, dice_loss - 0.09839, iou_score - 0.8602]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 15/15 [00:06<00:00,  2.17it/s, dice_loss - 0.2026, iou_score - 0.8103]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.06it/s, dice_loss - 0.09967, iou_score - 0.8587]
#
# Epoch: 36
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2062, iou_score - 0.8093]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.42it/s, dice_loss - 0.09847, iou_score - 0.8613]
# Model saved!
#
# Epoch: 37
# train: 100%|██████████| 15/15 [00:06<00:00,  2.24it/s, dice_loss - 0.2133, iou_score - 0.8069]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.79it/s, dice_loss - 0.09635, iou_score - 0.8616]
# Model saved!
#
# Epoch: 38
# train: 100%|██████████| 15/15 [00:06<00:00,  2.14it/s, dice_loss - 0.2122, iou_score - 0.8058]
# valid: 100%|██████████| 30/30 [00:00<00:00, 48.22it/s, dice_loss - 0.0964, iou_score - 0.8621]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 15/15 [00:06<00:00,  2.20it/s, dice_loss - 0.206, iou_score - 0.8104]
# valid: 100%|██████████| 30/30 [00:00<00:00, 50.09it/s, dice_loss - 0.09625, iou_score - 0.8625]
# Model saved!

# %%
#out = model(torch.from_numpy(train_data).float())

# %%
training_img_data.shape
# Out:
# (590, 1, 224, 224)

# %%
test_img_data.shape
# Out:
# (251, 1, 224, 224)

# %%
test_ds = SeismicDataset(
        test_img_data,
        preprocessing=get_preprocessing(preprocessing_fn),
        augmentation=get_validation_augmentation(),
        labels=labels
)
val_loader = DataLoader(test_ds, batch_size=4)

# %%
with torch.no_grad():
    all_predictions = []
    for fold in np.arange(NFOLDS):
        fold_predictions = []
        model = torch.load(f'./solution1/best_model_{fold}.pth')
        model = model.to(DEVICE)
        for batch in val_loader:
            predictions = model(batch.to(DEVICE))
            predictions = predictions.detach().cpu().numpy()
            fold_predictions.append(predictions)
        fold_predictions = np.concatenate(fold_predictions, 0)
        all_predictions.append(fold_predictions)
        del model
    #torch.load()
    #for batch in val_loader:

# %%
predictions = np.mean(all_predictions, 0)

# %%
all_predictions = []
for pred in predictions:
    p = cv2.resize(np.moveaxis(pred, 0, -1), (782, 1006))
    p = np.argmax(p, -1)
    all_predictions.append(labels[p])
all_predictions = np.stack(all_predictions, -1)

# %%
with np.load('../data/sample_submission_1.npz') as dataset:
    print(list(dataset.keys()))
    sample = dataset['prediction']
# Out:
# ['prediction']

# %%
assert sample.shape==all_predictions.shape

# %%
np.savez_compressed("solution1/submission_solution1.npz", prediction=all_predictions)
